# %%
# !pip install pyLDAvis
# Out:
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.4.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.24.2 in /opt/conda/lib/python3.13/site-packages (from pyLDAvis) (2.4.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.13/site-packages (from pyLDAvis) (1.17.1)
# Requirement already satisfied: pandas>=2.0.0 in /opt/conda/lib/python3.13/site-packages (from pyLDAvis) (2.2.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.13/site-packages (from pyLDAvis) (1.5.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.13/site-packages (from pyLDAvis) (3.1.6)
# Requirement already satisfied: numexpr in /opt/conda/lib/python3.13/site-packages (from pyLDAvis) (2.14.1)
# Collecting funcy (from pyLDAvis)
#   Downloading funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /opt/conda/lib/python3.13/site-packages (from pyLDAvis) (1.8.0)
# Collecting gensim (from pyLDAvis)
#   Downloading gensim-4.4.0-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.13/site-packages (from pyLDAvis) (82.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.13/site-packages (from pandas>=2.0.0->pyLDAvis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.13/site-packages (from pandas>=2.0.0->pyLDAvis) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.13/site-packages (from pandas>=2.0.0->pyLDAvis) (2026.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/conda/lib/python3.13/site-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.6.0)
# Requirement already satisfied: smart_open>=1.8.1 in /opt/conda/lib/python3.13/site-packages (from gensim->pyLDAvis) (7.6.1)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.13/site-packages (from smart_open>=1.8.1->gensim->pyLDAvis) (2.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.13/site-packages (from jinja2->pyLDAvis) (3.0.3)
# Downloading pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 9.6 MB/s  0:00:00 eta 0:00:01
# Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Downloading gensim-4.4.0-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.8/27.8 MB 19.4 MB/s  0:00:01m0:00:0100:01
# Installing collected packages: funcy, gensim, pyLDAvis
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pyLDAvis]2/3 [pyLDAvis]
# Successfully installed funcy-2.0 gensim-4.4.0 pyLDAvis-3.4.1

# %%
import os
import sys
import re

# =========================================================
# 1. ÉP VERSION PYSPARK (PHẢI CHẠY ĐẦU TIÊN TRƯỚC KHI IMPORT)
# =========================================================
modules_to_remove = [mod for mod in sys.modules if mod.startswith('pyspark') or mod.startswith('py4j')]
for mod in modules_to_remove: 
    del sys.modules[mod]

sys.path = [p for p in sys.path if "/usr/local/spark" not in p]
if "PYTHONPATH" in os.environ: 
    del os.environ["PYTHONPATH"]
    
conda_site_packages = "/opt/conda/lib/python3.13/site-packages"
if conda_site_packages not in sys.path: 
    sys.path.insert(0, conda_site_packages)
    
os.environ["SPARK_HOME"] = os.path.join(conda_site_packages, "pyspark")
os.environ["PYSPARK_PYTHON"] = "python3"
os.environ["PYSPARK_DRIVER_PYTHON"] = "python3"


# =========================================================
# 2. BÂY GIỜ MỚI IMPORT PYSPARK VÀ KHỞI TẠO SESSION
# =========================================================
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, to_date

spark = SparkSession.builder \
    .appName("Lemmatization_Pipeline") \
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.4,com.amazonaws:aws-java-sdk-bundle:1.12.262,org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.5.0") \
    .config("spark.hadoop.fs.s3a.endpoint", "http://minio:9000") \
    .config("spark.hadoop.fs.s3a.access.key", "dataNLPmining-lab") \
    .config("spark.hadoop.fs.s3a.secret.key", "dataNLPmining-lab") \
    .config("spark.hadoop.fs.s3a.path.style.access", "true") \
    .config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false") \
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
    .config("spark.hadoop.fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider") \
    .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
    .config("spark.sql.catalog.my_catalog", "org.apache.iceberg.spark.SparkCatalog") \
    .config("spark.sql.catalog.my_catalog.type", "hadoop") \
    .config("spark.sql.catalog.my_catalog.warehouse", "s3a://raw-financial-data/iceberg_warehouse") \
    .getOrCreate()


# =========================================================
# 3. VÁ LỖI THỜI GIAN HADOOP
# =========================================================
hadoop_conf = spark._jsc.hadoopConfiguration()
iterator = hadoop_conf.iterator()
while iterator.hasNext():
    entry = iterator.next()
    val = str(entry.getValue()).strip().lower()
    match = re.fullmatch(r"(\d+)([smhd])", val)
    if match:
        num, unit = int(match.group(1)), match.group(2)
        ms_val = num * 1000 if unit == 's' else num * 60000 if unit == 'm' else num * 3600000 if unit == 'h' else num * 86400000
        hadoop_conf.set(entry.getKey(), str(ms_val))

print("✅ Khởi tạo Spark và môi trường hoàn tất!")
# Out:
# ✅ Khởi tạo Spark và môi trường hoàn tất!

# %%
import re
import spacy
from pyspark.sql.functions import col, udf
from pyspark.sql.types import ArrayType, StringType


nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])

def extract_lemmas(text):
    if not text: return []
    text = re.sub(r'[^a-z\s]', ' ', str(text).lower())
    text = re.sub(r'\s+', ' ', text).strip()
    if not text: return []
    return [token.lemma_ for token in nlp(text) if not token.is_stop and len(token.text.strip()) > 1]
print("✅ Đang xử lý và lưu bảng Lemma!")

lemma_udf = udf(extract_lemmas, ArrayType(StringType()))

# Đọc dữ liệu từ Raw Zone
df_news = spark.read.table("my_catalog.raw_zone_finnhub.news_data_clean")

# Xử lý Lemma
df_lemmas = df_news.select(
    col("id"),
    col("published_at"),
    lemma_udf(col("title")).alias("title_lemmas"),
    lemma_udf(col("summary")).alias("summary_lemmas")
)

# Lưu vào Processed Zone
spark.sql("CREATE NAMESPACE IF NOT EXISTS my_catalog.processed_zone")
df_lemmas.write.format("iceberg").mode("overwrite").saveAsTable("my_catalog.processed_zone_finnhub.news_lemmas")
print("✅ Đã xử lý và lưu bảng Lemma thành công!")
# Out:
# ✅ Đang xử lý và lưu bảng Lemma!
# ✅ Đã xử lý và lưu bảng Lemma thành công!
