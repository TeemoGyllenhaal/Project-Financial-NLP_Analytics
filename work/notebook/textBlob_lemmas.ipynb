# %%
import os
import sys
import re

# =========================================================
# 1. ÉP VERSION PYSPARK (PHẢI CHẠY ĐẦU TIÊN TRƯỚC KHI IMPORT)
# =========================================================
modules_to_remove = [mod for mod in sys.modules if mod.startswith('pyspark') or mod.startswith('py4j')]
for mod in modules_to_remove: 
    del sys.modules[mod]

sys.path = [p for p in sys.path if "/usr/local/spark" not in p]
if "PYTHONPATH" in os.environ: 
    del os.environ["PYTHONPATH"]
    
conda_site_packages = "/opt/conda/lib/python3.13/site-packages"
if conda_site_packages not in sys.path: 
    sys.path.insert(0, conda_site_packages)
    
os.environ["SPARK_HOME"] = os.path.join(conda_site_packages, "pyspark")
os.environ["PYSPARK_PYTHON"] = "python3"
os.environ["PYSPARK_DRIVER_PYTHON"] = "python3"


# =========================================================
# 2. BÂY GIỜ MỚI IMPORT PYSPARK VÀ KHỞI TẠO SESSION
# =========================================================
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, concat_ws, udf
from pyspark.sql.types import FloatType

spark = SparkSession.builder \
    .appName("textBlob_lemmas_Pipeline") \
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.4,com.amazonaws:aws-java-sdk-bundle:1.12.262,org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.5.0") \
    .config("spark.hadoop.fs.s3a.endpoint", "http://minio:9000") \
    .config("spark.hadoop.fs.s3a.access.key", "dataNLPmining-lab") \
    .config("spark.hadoop.fs.s3a.secret.key", "dataNLPmining-lab") \
    .config("spark.hadoop.fs.s3a.path.style.access", "true") \
    .config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false") \
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
    .config("spark.hadoop.fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider") \
    .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
    .config("spark.sql.catalog.my_catalog", "org.apache.iceberg.spark.SparkCatalog") \
    .config("spark.sql.catalog.my_catalog.type", "hadoop") \
    .config("spark.sql.catalog.my_catalog.warehouse", "s3a://raw-financial-data/iceberg_warehouse") \
    .getOrCreate()


# =========================================================
# 3. VÁ LỖI THỜI GIAN HADOOP
# =========================================================
hadoop_conf = spark._jsc.hadoopConfiguration()
iterator = hadoop_conf.iterator()
while iterator.hasNext():
    entry = iterator.next()
    val = str(entry.getValue()).strip().lower()
    match = re.fullmatch(r"(\d+)([smhd])", val)
    if match:
        num, unit = int(match.group(1)), match.group(2)
        ms_val = num * 1000 if unit == 's' else num * 60000 if unit == 'm' else num * 3600000 if unit == 'h' else num * 86400000
        hadoop_conf.set(entry.getKey(), str(ms_val))

print("✅ Khởi tạo Spark và môi trường hoàn tất!")
# Out:
# ✅ Khởi tạo Spark và môi trường hoàn tất!

# %%
# !pip install TextBlob
# Out:
# Requirement already satisfied: TextBlob in /opt/conda/lib/python3.13/site-packages (0.20.0)
# Requirement already satisfied: nltk>=3.9 in /opt/conda/lib/python3.13/site-packages (from TextBlob) (3.9.4)
# Requirement already satisfied: click in /opt/conda/lib/python3.13/site-packages (from nltk>=3.9->TextBlob) (8.3.3)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.13/site-packages (from nltk>=3.9->TextBlob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.13/site-packages (from nltk>=3.9->TextBlob) (2026.5.9)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.13/site-packages (from nltk>=3.9->TextBlob) (4.67.3)

# %%
from textblob import TextBlob

#file parquet nằm trong iceberg-warehouse
df_lemmas = spark.read.table("my_catalog.processed_zone_finnhub.news_lemmas")
df_lemmas.show(5, truncate=False)
# Out:
# +---------+-------------------+-------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |id       |published_at       |title_lemmas                                                                                     |summary_lemmas                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# +---------+-------------------+-------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |140651233|2026-06-17 09:37:30|[market, chatter, jpmorgan, google, firm, ask, preserve, record, epstein, ranch, investigation]  |[jpmorgan, chase, jpm, alphabet, goog, googl, google, dozen, company]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |140651234|2026-06-17 09:09:41|[uk, regulator, set, new, rule, google, search, boost, competition]                              |[britain, competition, watchdog, order, google, provide, great, transparency, search, ranking, work, new, requirement, aim, secure, fair, deal, business, improve, tech, giant, service, country, require, google, improve, transparency, fairness, search, result, rank, second, require, google, allow, user, search, datum, authorise, party, competition, market, authority, say, statement, wednesday, regulator, flag, concern, google, dominance, search, designate, company, strategic, market, status, allow, set, target, rule, increase, transparency]|
# |140650770|2026-06-17 06:55:00|[google, cloud, model, garden, platform, exclusive, customer, hub, ai, innovation, collaboration]|[google, cloud, summit, london, model, garden, platform, opening, london, year, premier, invitation, google, experience, center, gec, google, strategic, customer, flagship, emea, facility, offer, purpose, build, confidential, environment, suite, executive, senior, leader, partner, learn, drive, digital, transformation, organization, google, cloud, entire, product, portfolio, include, industry, lead, generative, ai, agentic, ai, mod]                                                                                                             |
# |140650768|2026-06-17 06:30:00|[social, medium, political, problem, time, go, away]                                             |[major, country, seek, ban, social, medium, young, user, investor, need, pay, attention]                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |140649980|2026-06-17 03:52:00|[custom, ai, chip, come, nvidia, crown, company, quietly, cash]                                  |[large, cloud, company, design, ai, chip, semiconductor, specialist, capture, fast, grow, slice, spending]                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# +---------+-------------------+-------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
# 1. Định nghĩa các hàm xử lý TextBlob (Giữ nguyên logic kiểm tra Null của bạn)
def get_polarity(text):
    if text is None or text == "":
        return 0.0
    return TextBlob(text).sentiment.polarity

def get_subjectivity(text):
    if text is None or text == "":
        return 0.0
    return TextBlob(text).sentiment.subjectivity

# Đăng ký UDF với PySpark
udf_polarity = udf(get_polarity, FloatType()) ##(Độ phân cực / Sắc thái cảm xúc)
udf_subjectivity = udf(get_subjectivity, FloatType()) ## Subjectivity (Tính chủ quan)

# 2. Nối các phần tử mảng (Array) thành Chuỗi (String) cho cả Title và Summary
# Định dạng concat_ws sẽ tự động bỏ qua các phần tử null nếu có trong mảng
df_processed = df_lemmas \
    .withColumn("title_text", concat_ws(" ", col("title_lemmas"))) \
    .withColumn("summary_text", concat_ws(" ", col("summary_lemmas")))


# 3. Áp dụng UDF để tính điểm độc lập cho tiêu đề và tóm tắt
df_final = df_processed \
    .withColumn("title_polarity", udf_polarity(col("title_text"))) \
    .withColumn("title_subjectivity", udf_subjectivity(col("title_text"))) \
    .withColumn("summary_polarity", udf_polarity(col("summary_text"))) \
    .withColumn("summary_subjectivity", udf_subjectivity(col("summary_text")))

# 4. Kiểm tra cấu trúc phân lớp điểm số vừa tạo
df_final.select(
    "title_text", 
    "title_polarity", 
    "title_subjectivity",
    "summary_text", 
    "summary_polarity", 
    "summary_subjectivity"
).show(5, truncate=50) # Giới hạn độ dài hiển thị chuỗi là 50 ký tự cho đỡ rối mắt
# Out:
# +--------------------------------------------------+--------------+------------------+--------------------------------------------------+----------------+--------------------+
# |                                        title_text|title_polarity|title_subjectivity|                                      summary_text|summary_polarity|summary_subjectivity|
# +--------------------------------------------------+--------------+------------------+--------------------------------------------------+----------------+--------------------+
# |market chatter jpmorgan google firm ask preserv...|          -0.2|               0.4|jpmorgan chase jpm alphabet goog googl google d...|             0.0|                 0.0|
# |uk regulator set new rule google search boost c...|    0.13636364|        0.45454547|britain competition watchdog order google provi...|      0.17662337|           0.6577922|
# |google cloud model garden platform exclusive cu...|           0.0|               0.0|google cloud summit london model garden platfor...|           0.025|             0.28125|
# |      social medium political problem time go away|   0.016666668|       0.083333336|major country seek ban social medium young user...|      0.06527778|          0.32222223|
# |custom ai chip come nvidia crown company quietl...|           0.0|        0.33333334|large cloud company design ai chip semiconducto...|      0.20714286|          0.51428574|
# +--------------------------------------------------+--------------+------------------+--------------------------------------------------+----------------+--------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col, when

# 1. Định nghĩa các mốc điểm (Threshold) phù hợp với bản chất từng thang điểm
# Đối với Polarity (Cảm xúc)
POLARITY_POS_THRES = 0.1
POLARITY_NEG_THRES = -0.1

# Đối với Subjectivity (Tính chủ quan: từ 0.0 đến 1.0)
# Thường mốc trung vị 0.5 được chọn để phân tách Khách quan và Chủ quan
SUBJECTIVITY_THRES = 0.5

# 2. Tạo cột nhãn cảm xúc cho Title
df_labeled = df_final.withColumn(
    "title_polarity_sentiment",
    when(col("title_polarity") >= POLARITY_POS_THRES, "Tích cực 🟢")
    .when(col("title_polarity") <= POLARITY_NEG_THRES, "Tiêu cực 🔴")
    .otherwise("Trung tính ⚪")
)

# 3. Kế thừa từ df_labeled trước đó để tạo nhãn cảm xúc cho Summary (Tránh ghi đè)
df_labeled = df_labeled.withColumn(
    "summary_polarity_sentiment",
    when(col("summary_polarity") >= POLARITY_POS_THRES, "Tích cực 🟢")
    .when(col("summary_polarity") <= POLARITY_NEG_THRES, "Tiêu cực 🔴")
    .otherwise("Trung tính ⚪")
)

# 4. Phân loại tính chủ quan cho Title (Sử dụng đúng thang điểm dương)
df_labeled = df_labeled.withColumn(
    "title_subjectivity_sentiment",
    when(col("title_subjectivity") >= SUBJECTIVITY_THRES, "Chủ quan 🧠")
    .otherwise("Khách quan 📊")
)

# 5. Phân loại tính chủ quan cho Summary
df_labeled = df_labeled.withColumn(
    "summary_subjectivity_sentiment",
    when(col("summary_subjectivity") >= SUBJECTIVITY_THRES, "Chủ quan 🧠")
    .otherwise("Khách quan 📊")
)

# 6. Hiển thị đối chiếu kết quả (Sửa chính xác tên các cột đã khởi tạo)
df_labeled.select(
    "title_polarity", "title_polarity_sentiment",
    "summary_polarity", "summary_polarity_sentiment",
    "title_subjectivity", "title_subjectivity_sentiment",
    "summary_subjectivity", "summary_subjectivity_sentiment"
).show(50, truncate=False)
# Out:
# +--------------+------------------------+----------------+--------------------------+------------------+----------------------------+--------------------+------------------------------+
# |title_polarity|title_polarity_sentiment|summary_polarity|summary_polarity_sentiment|title_subjectivity|title_subjectivity_sentiment|summary_subjectivity|summary_subjectivity_sentiment|
# +--------------+------------------------+----------------+--------------------------+------------------+----------------------------+--------------------+------------------------------+
# |-0.2          |Tiêu cực 🔴             |0.0             |Trung tính ⚪              |0.4               |Khách quan 📊               |0.0                 |Khách quan 📊                 |
# |0.13636364    |Tích cực 🟢             |0.17662337      |Tích cực 🟢               |0.45454547        |Khách quan 📊               |0.6577922           |Chủ quan 🧠                   |
# |0.0           |Trung tính ⚪            |0.025           |Trung tính ⚪              |0.0               |Khách quan 📊               |0.28125             |Khách quan 📊                 |
# |0.016666668   |Trung tính ⚪            |0.06527778      |Trung tính ⚪              |0.083333336       |Khách quan 📊               |0.32222223          |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |0.20714286      |Tích cực 🟢               |0.33333334        |Khách quan 📊               |0.51428574          |Chủ quan 🧠                   |
# |0.0           |Trung tính ⚪            |-0.110416666    |Tiêu cực 🔴               |0.0               |Khách quan 📊               |0.25625             |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |0.14818181      |Tích cực 🟢               |0.0               |Khách quan 📊               |0.49727273          |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |-0.06666667     |Trung tính ⚪              |0.0               |Khách quan 📊               |0.53809524          |Chủ quan 🧠                   |
# |6.938894E-18  |Trung tính ⚪            |0.022857143     |Trung tính ⚪              |0.175             |Khách quan 📊               |0.29142857          |Khách quan 📊                 |
# |0.16          |Tích cực 🟢             |0.14818181      |Tích cực 🟢               |0.54              |Chủ quan 🧠                 |0.49727273          |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |0.0             |Trung tính ⚪              |0.0               |Khách quan 📊               |0.1                 |Khách quan 📊                 |
# |0.0625        |Trung tính ⚪            |0.28333333      |Tích cực 🟢               |0.5               |Chủ quan 🧠                 |0.53333336          |Chủ quan 🧠                   |
# |0.13636364    |Tích cực 🟢             |0.5             |Tích cực 🟢               |0.45454547        |Khách quan 📊               |0.75                |Chủ quan 🧠                   |
# |0.0           |Trung tính ⚪            |0.07559524      |Trung tính ⚪              |0.0               |Khách quan 📊               |0.51428574          |Chủ quan 🧠                   |
# |0.0           |Trung tính ⚪            |0.01875         |Trung tính ⚪              |1.0               |Chủ quan 🧠                 |0.675               |Chủ quan 🧠                   |
# |0.0           |Trung tính ⚪            |-0.125          |Tiêu cực 🔴               |0.0               |Khách quan 📊               |0.125               |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |0.0             |Trung tính ⚪              |0.0               |Khách quan 📊               |0.1                 |Khách quan 📊                 |
# |-0.05         |Trung tính ⚪            |0.0             |Trung tính ⚪              |0.4               |Khách quan 📊               |0.0                 |Khách quan 📊                 |
# |0.16          |Tích cực 🟢             |0.0             |Trung tính ⚪              |0.54              |Chủ quan 🧠                 |0.0                 |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |0.46666667      |Tích cực 🟢               |0.0               |Khách quan 📊               |0.7083333           |Chủ quan 🧠                   |
# |0.0           |Trung tính ⚪            |-0.05           |Trung tính ⚪              |0.0               |Khách quan 📊               |0.4                 |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |0.0             |Trung tính ⚪              |0.06666667        |Khách quan 📊               |0.06666667          |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |0.06            |Trung tính ⚪              |0.0               |Khách quan 📊               |0.55                |Chủ quan 🧠                   |
# |0.0           |Trung tính ⚪            |0.3121212       |Tích cực 🟢               |0.0               |Khách quan 📊               |0.28484848          |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |0.4             |Tích cực 🟢               |0.0               |Khách quan 📊               |0.7                 |Chủ quan 🧠                   |
# |0.0           |Trung tính ⚪            |0.0             |Trung tính ⚪              |0.1               |Khách quan 📊               |0.0                 |Khách quan 📊                 |
# |-0.8          |Tiêu cực 🔴             |0.10714286      |Tích cực 🟢               |0.9               |Chủ quan 🧠                 |0.3                 |Khách quan 📊                 |
# |0.41666666    |Tích cực 🟢             |0.7             |Tích cực 🟢               |0.71666664        |Chủ quan 🧠                 |0.6                 |Chủ quan 🧠                   |
# |0.0           |Trung tính ⚪            |0.020535715     |Trung tính ⚪              |0.1               |Khách quan 📊               |0.29315478          |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |-0.009090909    |Trung tính ⚪              |0.0               |Khách quan 📊               |0.43636364          |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |0.16818182      |Tích cực 🟢               |0.0               |Khách quan 📊               |0.5272727           |Chủ quan 🧠                   |
# |-0.25         |Tiêu cực 🔴             |0.16818182      |Tích cực 🟢               |0.25              |Khách quan 📊               |0.5272727           |Chủ quan 🧠                   |
# |0.2375        |Tích cực 🟢             |0.3625          |Tích cực 🟢               |0.575             |Chủ quan 🧠                 |0.7                 |Chủ quan 🧠                   |
# |0.13636364    |Tích cực 🟢             |-0.03181818     |Trung tính ⚪              |0.45454547        |Khách quan 📊               |0.42727274          |Khách quan 📊                 |
# |0.1875        |Tích cực 🟢             |0.08956044      |Trung tính ⚪              |0.375             |Khách quan 📊               |0.32527474          |Khách quan 📊                 |
# |0.13636364    |Tích cực 🟢             |0.045454547     |Trung tính ⚪              |0.45454547        |Khách quan 📊               |0.5681818           |Chủ quan 🧠                   |
# |0.0           |Trung tính ⚪            |0.056565657     |Trung tính ⚪              |0.75              |Chủ quan 🧠                 |0.17373738          |Khách quan 📊                 |
# |-0.13333334   |Tiêu cực 🔴             |-0.23333333     |Tiêu cực 🔴               |0.26666668        |Khách quan 📊               |0.7                 |Chủ quan 🧠                   |
# |0.43333334    |Tích cực 🟢             |0.15416667      |Tích cực 🟢               |0.73333335        |Chủ quan 🧠                 |0.6041667           |Chủ quan 🧠                   |
# |0.0           |Trung tính ⚪            |0.115           |Tích cực 🟢               |0.0               |Khách quan 📊               |0.435               |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |0.0             |Trung tính ⚪              |0.0               |Khách quan 📊               |0.0                 |Khách quan 📊                 |
# |-0.1          |Tiêu cực 🔴             |-0.3            |Tiêu cực 🔴               |0.1               |Khách quan 📊               |0.6                 |Chủ quan 🧠                   |
# |0.0           |Trung tính ⚪            |0.31666666      |Tích cực 🟢               |0.0               |Khách quan 📊               |0.5416667           |Chủ quan 🧠                   |
# |0.0           |Trung tính ⚪            |0.1             |Tích cực 🟢               |0.0               |Khách quan 📊               |0.13333334          |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |0.0             |Trung tính ⚪              |0.0               |Khách quan 📊               |0.0                 |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |0.1875          |Tích cực 🟢               |1.0               |Chủ quan 🧠                 |0.525               |Chủ quan 🧠                   |
# |0.0           |Trung tính ⚪            |0.041666668     |Trung tính ⚪              |0.4               |Khách quan 📊               |0.29305556          |Khách quan 📊                 |
# |-0.25         |Tiêu cực 🔴             |0.014285714     |Trung tính ⚪              |0.25              |Khách quan 📊               |0.42380953          |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |0.33333334      |Tích cực 🟢               |0.0               |Khách quan 📊               |0.33333334          |Khách quan 📊                 |
# |0.0           |Trung tính ⚪            |-0.033333335    |Trung tính ⚪              |0.0               |Khách quan 📊               |0.23333333          |Khách quan 📊                 |
# +--------------+------------------------+----------------+--------------------------+------------------+----------------------------+--------------------+------------------------------+
# only showing top 50 rows

# %%
# 1. Bắt buộc phải có TÊN CATALOG ở đầu (ví dụ: my_catalog)
# Hãy thay 'my_catalog' bằng đúng tên catalog bạn đã cấu hình trong Spark
iceberg_table_path = "my_catalog.processed_zone_finnhub.news_textBlob_lemmas_sentiment_score"

print(f"Đang ghi dữ liệu vào bảng Iceberg: {iceberg_table_path}...")

# 2. Sử dụng API tiêu chuẩn với format("iceberg") và saveAsTable
df_labeled.write \
    .format("iceberg") \
    .mode("overwrite") \
    .saveAsTable(iceberg_table_path)

print("Lưu dữ liệu vào Iceberg thành công!")
# Out:
# Đang ghi dữ liệu vào bảng Iceberg: my_catalog.processed_zone_finnhub.news_textBlob_lemmas_sentiment_score...
# Lưu dữ liệu vào Iceberg thành công!
